# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dataset = pd.read_csv("C:/Users/repair/Desktop/IEEE ML/Assignment 1/brasil-real-estate-1.csv")
dataset.shape
# Out:
# (4628, 16)

# %%
dataset.iloc[:,:].dtypes
# Out:
# operation                      object
# property_type                  object
# place_with_parent_names        object
# lat-lon                        object
# price                         float64
# currency                       object
# price_aprox_local_currency    float64
# price_aprox_usd               float64
# surface_total_in_m2           float64
# surface_covered_in_m2         float64
# price_usd_per_m2              float64
# price_per_m2                  float64
# floor                         float64
# rooms                         float64
# expenses                      float64
# properati_url                  object
# dtype: object

# %%
missing_values_count = dataset.isnull().sum()
missing_values_count[:]
# Out:
# operation                        0
# property_type                    0
# place_with_parent_names          0
# lat-lon                        499
# price                           70
# currency                        70
# price_aprox_local_currency      70
# price_aprox_usd                 70
# surface_total_in_m2           2883
# surface_covered_in_m2          186
# price_usd_per_m2              3381
# price_per_m2                   357
# floor                         4326
# rooms                         4502
# expenses                      4627
# properati_url                    0
# dtype: int64

# %%
newdataset=dataset.fillna(method='bfill', axis=0).fillna(0)

# %%
newdataset
# Out:
#      operation property_type                   place_with_parent_names  \
# 1         sell         house         |Tlalpan|Distrito Federal|México|
# 2         sell     apartment   |Benito Juárez|Distrito Federal|México|
# 3         sell     apartment   |Benito Juárez|Distrito Federal|México|
# 4         sell     apartment         |Tlalpan|Distrito Federal|México|
# 5         sell     apartment      |Iztapalapa|Distrito Federal|México|
# ...        ...           ...                                       ...
# 4624      sell     apartment         |Solidaridad|Quintana Roo|México|
# 4625      sell         house  |Álvaro Obregón|Distrito Federal|México|
# 4626      sell     apartment      |Cuauhtémoc|Distrito Federal|México|
# 4627      sell         house  |Miguel Hidalgo|Distrito Federal|México|
# 4628      sell     apartment      |Cuauhtémoc|Distrito Federal|México|
#
#                            lat-lon       price currency  \
# 1           19.2881277;-99.1383849   4890000.0      MXN
# ...

# %%
missing_values_count = newdataset.isnull().sum()
missing_values_count[:]
# Out:
# operation                     0
# property_type                 0
# place_with_parent_names       0
# lat-lon                       0
# price                         0
# currency                      0
# price_aprox_local_currency    0
# price_aprox_usd               0
# surface_total_in_m2           0
# surface_covered_in_m2         0
# price_usd_per_m2              0
# price_per_m2                  0
# floor                         0
# rooms                         0
# expenses                      0
# properati_url                 0
# dtype: int64

# %%
dataset.describe()
# Out:
#               price  price_aprox_local_currency  price_aprox_usd  \
# count  4.558000e+03                4.558000e+03     4.558000e+03
# mean   3.381425e+06                5.590856e+06     2.972515e+05
# std    5.939553e+06                1.075184e+07     5.716477e+05
# min    6.280000e+04                1.471566e+05     7.823940e+03
# 25%    9.010000e+05                1.223220e+06     6.503550e+04
# 50%    1.866468e+06                2.633556e+06     1.400195e+05
# 75%    3.750000e+06                5.380467e+06     2.860657e+05
# max    2.337267e+08                2.633190e+08     1.400000e+07
#
#        surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  \
# count          1745.000000           4.442000e+03       1247.000000
# mean            402.796562           1.499219e+04       1774.342033
# std            3173.915879           9.864887e+05       1410.006872
# min               0.000000           0.000000e+00          6.083353
# ...

# %%
newdataset.describe()
# Out:
#               price  price_aprox_local_currency  price_aprox_usd  \
# count  4.628000e+03                4.628000e+03     4.628000e+03
# mean   3.379517e+06                5.575503e+06     2.964353e+05
# std    5.909052e+06                1.068841e+07     5.682754e+05
# min    6.280000e+04                1.471566e+05     7.823940e+03
# 25%    9.050000e+05                1.229306e+06     6.535907e+04
# 50%    1.872545e+06                2.637686e+06     1.402390e+05
# 75%    3.750000e+06                5.376751e+06     2.858681e+05
# max    2.337267e+08                2.633190e+08     1.400000e+07
#
#        surface_total_in_m2  surface_covered_in_m2  price_usd_per_m2  \
# count          4628.000000           4.628000e+03       4628.000000
# mean            371.936474           1.441457e+04       1786.769187
# std            2788.680448           9.664620e+05       1394.289071
# min               0.000000           0.000000e+00          6.083353
# ...

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=dataset)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=dataset['rooms'])
# Out:
# <AxesSubplot:ylabel='rooms'>

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=dataset['surface_total_in_m2'], y=dataset['price'],)
# Out:
# <AxesSubplot:xlabel='surface_total_in_m2', ylabel='price'>

# %%
plt.figure(figsize=(16,6))
sns.histplot(dataset['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>
